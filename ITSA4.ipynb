# %% [markdown]
# <a href="https://colab.research.google.com/github/cadu77/ITSA4/blob/main/ITSA4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ciência de Dados para Finanças**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Lendo a Base de Dados
Base_Dados = pd.read_csv('/content/drive/MyDrive/Datasets/Itaúsa ITSA4 - Histórico  InfoMoney.csv')

# dimensão
Base_Dados.shape
# Out:
# (50, 7)

# %%
# Head
Base_Dados.head()
# Out:
#          DATA ABERTURA FECHAMENTO VARIAÇÃO MÍNIMO MÁXIMO   VOLUME
# 0  03/01/2023     8,37       8,15    -2,51   8,12   8,41  140,34M
# 1  02/01/2023     8,44       8,36    -1,76   8,25   8,45  126,58M
# 2  29/12/2022     8,58       8,51    -0,47   8,47   8,65  146,59M
# 3  28/12/2022     8,40       8,55     2,03   8,37   8,56   91,90M
# 4  27/12/2022     8,51       8,38    -1,06   8,31   8,54  104,41M

# %%
Base_Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DATA        50 non-null     object
#  1   ABERTURA    50 non-null     object
#  2   FECHAMENTO  50 non-null     object
#  3   VARIAÇÃO    50 non-null     object
#  4   MÍNIMO      50 non-null     object
#  5   MÁXIMO      50 non-null     object
#  6   VOLUME      50 non-null     object
# dtypes: object(7)
# memory usage: 2.9+ KB

# %%
# Series Temporais
Dados = Base_Dados.set_index('DATA')

Dados.head()
# Out:
#            ABERTURA FECHAMENTO VARIAÇÃO MÍNIMO MÁXIMO   VOLUME
# DATA
# 03/01/2023     8,37       8,15    -2,51   8,12   8,41  140,34M
# 02/01/2023     8,44       8,36    -1,76   8,25   8,45  126,58M
# 29/12/2022     8,58       8,51    -0,47   8,47   8,65  146,59M
# 28/12/2022     8,40       8,55     2,03   8,37   8,56   91,90M
# 27/12/2022     8,51       8,38    -1,06   8,31   8,54  104,41M

# %%
plt.figure(figsize=(20,20))
plt.title('Análise das ações da ITAUSA - Fechamento')
plt.plot(Dados.index, Dados['FECHAMENTO'])
